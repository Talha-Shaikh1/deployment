# %% [markdown]
# <a href="https://colab.research.google.com/github/Talha-Shaikh1/deployment/blob/main/Asssignement%2000%20to%2005/%20Assignment_00_to_05_index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Folder path define karo
folder_path = "/my_folder"

# Folder create karo agar exist nahi karta
os.makedirs(folder_path, exist_ok=True)
