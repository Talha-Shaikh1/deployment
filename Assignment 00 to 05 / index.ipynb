# %% [markdown]
# <a href="https://colab.research.google.com/github/Talha-Shaikh1/deployment/blob/main/Assignment%2000%20to%2005%20/%20index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Helloe Wordl")
# Out:
# Helloe Wordl

# %% [markdown]
# # New Section
